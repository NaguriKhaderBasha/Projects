# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install pandas
# Out:
# ...
#      -------------------------------------- 10.7/10.7 MB 291.4 kB/s eta 0:00:00
# ...
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# ...
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# ...
#      -------------------------------------- 15.6/15.6 MB 318.9 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'c:\Users\nagur\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the 'c:\Users\nagur\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.5/7.5 MB 352.4 kB/s eta 0:00:00
# ...
#   Using cached kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
# ...
#      ---------------------------------------- 2.5/2.5 MB 410.7 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.1/2.1 MB 625.6 kB/s eta 0:00:00
# ...
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# ...
#      ------------------------------------ 470.4/470.4 KB 817.3 kB/s eta 0:00:00
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\nagur\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# ...

# %%
p=np.array([10,15,20,25,30,35])
q=np.array([100,120,130,200,250,180])
plt.plot(p,q, marker="o", linestyle="-")
plt.xlabel("houwqrss")
plt.ylabel("minutwses")
plt.show()

# %%
plt.bar(p,q)
plt.show()

# %%
y=np.array([45, 80, 20, 15])
labelss=["apple","banana","orange","tomata"]
my=[0.1, 0, 0.1, 0]
plt.pie(y, labels=labelss,explode=my)
plt.show()

# %%
plt.hist(y)
plt.show()

# %%
df=pd.read_csv(r"C:\\Users\\nagur\\Downloads\\archive (3)\\housing_in_london_monthly_variables.csv")

# %%
df
# Out:
#              date            area  average_price       code  houses_sold  \
# 0      1995-01-01  city of london          91449  E09000001         17.0
# 1      1995-02-01  city of london          82203  E09000001          7.0
# 2      1995-03-01  city of london          79121  E09000001         14.0
# 3      1995-04-01  city of london          77101  E09000001          7.0
# 4      1995-05-01  city of london          84409  E09000001         10.0
# ...           ...             ...            ...        ...          ...
# 13544  2019-09-01         england         249942  E92000001      64605.0
# 13545  2019-10-01         england         249376  E92000001      68677.0
# 13546  2019-11-01         england         248515  E92000001      67814.0
# 13547  2019-12-01         england         250410  E92000001          NaN
# 13548  2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  borough_flag
# 0               NaN             1
# ...

# %%
df.head(200)
# Out:
#            date            area  average_price       code  houses_sold  \
# 0    1995-01-01  city of london          91449  E09000001         17.0
# 1    1995-02-01  city of london          82203  E09000001          7.0
# 2    1995-03-01  city of london          79121  E09000001         14.0
# 3    1995-04-01  city of london          77101  E09000001          7.0
# 4    1995-05-01  city of london          84409  E09000001         10.0
# ..          ...             ...            ...        ...          ...
# 195  2011-04-01  city of london         516319  E09000001         21.0
# 196  2011-05-01  city of london         459477  E09000001         28.0
# 197  2011-06-01  city of london         466525  E09000001         22.0
# 198  2011-07-01  city of london         420435  E09000001         19.0
# 199  2011-08-01  city of london         421486  E09000001         27.0
#
#      no_of_crimes  borough_flag
# 0             NaN             1
# 1             NaN             1
# ...

# %%
df.tail(10)
# Out:
#              date     area  average_price       code  houses_sold  \
# 13539  2019-04-01  england         245077  E92000001      59710.0
# 13540  2019-05-01  england         245255  E92000001      65387.0
# 13541  2019-06-01  england         246140  E92000001      66723.0
# 13542  2019-07-01  england         248562  E92000001      70681.0
# 13543  2019-08-01  england         249432  E92000001      75079.0
# 13544  2019-09-01  england         249942  E92000001      64605.0
# 13545  2019-10-01  england         249376  E92000001      68677.0
# 13546  2019-11-01  england         248515  E92000001      67814.0
# 13547  2019-12-01  england         250410  E92000001          NaN
# 13548  2020-01-01  england         247355  E92000001          NaN
#
#        no_of_crimes  borough_flag
# 13539           NaN             0
# 13540           NaN             0
# 13541           NaN             0
# 13542           NaN             0
# 13543           NaN             0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13549 entries, 0 to 13548
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           13549 non-null  object
#  1   area           13549 non-null  object
#  2   average_price  13549 non-null  int64
#  3   code           13549 non-null  object
#  4   houses_sold    13455 non-null  float64
#  5   no_of_crimes   7439 non-null   float64
#  6   borough_flag   13549 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 741.1+ KB

# %%
df.describe()
# Out:
#        average_price    houses_sold  no_of_crimes  borough_flag
# count   1.354900e+04   13455.000000   7439.000000  13549.000000
# mean    2.635197e+05    3893.994129   2158.352063      0.733338
# std     1.876175e+05   12114.402476    902.087742      0.442230
# min     4.072200e+04       2.000000      0.000000      0.000000
# 25%     1.323800e+05     247.000000   1623.000000      0.000000
# 50%     2.229190e+05     371.000000   2132.000000      1.000000
# 75%     3.368430e+05    3146.000000   2582.000000      1.000000
# max     1.463378e+06  132163.000000   7461.000000      1.000000

# %%
nul=df.isnull().sum().sort_values(ascending=False)
print(nul)
# Out:
# no_of_crimes     6110
# houses_sold        94
# date                0
# area                0
# average_price       0
# code                0
# borough_flag        0
# dtype: int64

# %%
df.drop('no_of_crimes',axis=1,inplace=True)

# %%
nul=df.isnull().sum().sort_values(ascending=False)
print(nul)
# Out:
# houses_sold      94
# date              0
# area              0
# average_price     0
# code              0
# borough_flag      0
# dtype: int64

# %%
df['houses_sold'].fillna(df.groupby('area')['houses_sold'].transform('mean'),inplace=True)

# %%
nul=df.isnull().sum().sort_values(ascending=False)
print(nul)
# Out:
# date             0
# area             0
# average_price    0
# code             0
# houses_sold      0
# borough_flag     0
# dtype: int64

# %%
date=[]

# %%
for i in df["date"]:
    date.append(i[0:4])

# %%
df['year']=date
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df['year']=date
#
# File c:\Users\nagur\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3950, in DataFrame.__setitem__(self, key, value)
#    3947     self._setitem_array([key], value)
#    3948 else:
#    3949     # set column
# -> 3950     self._set_item(key, value)
#
# File c:\Users\nagur\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4143, in DataFrame._set_item(self, key, value)
#    4133 def _set_item(self, key, value) -> None:
#    4134     """
#    4135     Add series to DataFrame in specified column.
#    4136
#    (...)
#    4141     ensure homogeneity.
#    4142     """
# -> 4143     value = self._sanitize_column(value)
#    4145     if (
#    4146         key in self.columns
#    4147         and value.ndim == 1
# ...

# %%
df.iloc[[0,10000]]
# Out:
#              date            area  average_price       code  houses_sold  \
# 0      1995-01-01  city of london          91449  E09000001         17.0
# 10000  2000-03-01    inner london         150488  E13000001       6153.0
#
#        no_of_crimes  borough_flag   year
# 0               NaN             1  1995-
# 10000           NaN             0  2000-

# %%
borough=df[df['borough_flag']==1]['area'].unique()
print(len(borough))
print(borough)
# Out:
# 33
# ['city of london' 'barking and dagenham' 'barnet' 'bexley' 'brent'
#  'bromley' 'camden' 'croydon' 'ealing' 'enfield' 'tower hamlets'
#  'greenwich' 'hackney' 'hammersmith and fulham' 'haringey' 'harrow'
#  'havering' 'hillingdon' 'hounslow' 'islington' 'kensington and chelsea'
#  'kingston upon thames' 'lambeth' 'lewisham' 'merton' 'newham' 'redbridge'
#  'richmond upon thames' 'southwark' 'sutton' 'waltham forest' 'wandsworth'
#  'westminster']

# %%
q=df[df['borough_flag']==0]['area'].unique()
len(q)
# Out:
# 12

# %%
df[df['borough_flag']==0]['area'].unique()
# Out:
# array(['south east', 'inner london', 'outer london', 'north east',
#        'north west', 'yorks and the humber', 'east midlands',
#        'west midlands', 'east of england', 'london', 'south west',
#        'england'], dtype=object)

# %%
cor=['south west','south east','east of england','east midlands','west midlands','yorks and the humber','north east','north west']

# %%
lnd=df[df['area'].isin(borough)]
eng=df[df['area'].isin(cor)]
print(lnd)
print("up")
print(eng)
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001     17.00000
# 1     1995-02-01  city of london          82203  E09000001      7.00000
# 2     1995-03-01  city of london          79121  E09000001     14.00000
# 3     1995-04-01  city of london          77101  E09000001      7.00000
# 4     1995-05-01  city of london          84409  E09000001     10.00000
# ...          ...             ...            ...        ...          ...
# 9933  2019-09-01     westminster         925955  E09000033    169.00000
# 9934  2019-10-01     westminster         927864  E09000033    168.00000
# 9935  2019-11-01     westminster         955615  E09000033    150.00000
# 9936  2019-12-01     westminster         968404  E09000033    356.83612
# 9937  2020-01-01     westminster        1019028  E09000033    356.83612
#
#       borough_flag  year
# 0                1  1995
# 1                1  1995
# ...

# %%
lnd_pr=lnd.groupby('date')['average_price'].mean()
eng_pr=eng.groupby('date')['average_price'].mean()

# %%
print(lnd_pr)
# Out:
# date
# 1995-01-01     81906.424242
# 1995-02-01     81527.969697
# 1995-03-01     81349.272727
# 1995-04-01     81432.515152
# 1995-05-01     82277.303030
#                   ...
# 2019-09-01    528443.060606
# 2019-10-01    525602.666667
# 2019-11-01    522975.878788
# 2019-12-01    524032.787879
# 2020-01-01    527450.393939
# Name: average_price, Length: 301, dtype: float64

# %%
print(eng_pr)
# Out:
# date
# 1995-01-01     50042.000
# 1995-02-01     50135.500
# 1995-03-01     50087.375
# 1995-04-01     50441.875
# 1995-05-01     50534.750
#                  ...
# 2019-09-01    217066.750
# 2019-10-01    216545.625
# 2019-11-01    216036.250
# 2019-12-01    217193.375
# 2020-01-01    214387.250
# Name: average_price, Length: 301, dtype: float64

# %%
plt.figure(figsize=(9,5))

lnd.pr.plot(y='average_price',color='royalblue',lw=2,label='London')
eng.pr.plot(y='average_price',color='firebrick',lw=2,label='England')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10996/2813068279.py in <module>
#       1 plt.figure(figsize=(9,5))
#       2
# ----> 3 lnd.pr.plot(y='average_price',color='royalblue',lw=2,label='London')
#       4 eng.pr.plot(y='average_price',color='firebrick',lw=2,label='England')
#       5
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'pr'
